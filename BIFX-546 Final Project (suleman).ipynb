# %%
"""
BIFX 546: Machine Learning for Bioinformatics
Project Progress Check-In #1: Preliminary EDA
Student: Suleman Mohammad
Date: March 18, 2026
Dataset: Parkinsons Telemonitoring

This script performs initial exploratory data analysis on the Parkinson's Telemonitoring dataset.
"""

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##To install the ucimlrepo package, you can use the following command in your terminal or command prompt:
# %pip install ucimlrepo
from ucimlrepo import fetch_ucirepo

##In Jupyter Notebook, you can use the following command to install the ucimlrepo package:
# !pip3 install -U ucimlrepo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
